# %% [markdown]
# # Advance Operation with Businees Examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Datastructre : [restaurant_id,2021,2022,2023,2024]

sales_data = np.array([
    [1, 150000, 180000, 220000, 250000], # Paradise Biryani (Biryani Chain)
    [2, 280000, 310000, 350000, 390000], # Barbeque Nation (Buffet Chain)
    [3, 50000, 65000, 85000, 110000],     # Wow! Momo (Quick Service Restaurant)
    [4, 120000, 140000, 165000, 175000],  # Sagar Ratna (South Indian Chain)
    [5, 450000, 480000, 510000, 530000],  # Fine Dining Restaurant (Stable Growth)
    [6, 30000, 35000, 32000, 40000],      # Small, local cafe (Volatile Growth)
    [7, 90000, 110000, 130000, 150000],   # Biryani By Kilo (Cloud Kitchen)
    [8, 200000, 240000, 270000, 300000],  # Haldiram's (Casual Dining/Sweets)
    [9, 70000, 85000, 92000, 98000],      # Pind Balluchi (North Indian)
    [10, 180000, 205000, 230000, 255000], # Mainland China (Chinese Cuisine)
])

print("=== Zomato sales analysis ===")
print("\n Sales data shape",sales_data.shape)

print(sales_data[:3])
# Out:
# === Zomato sales analysis ===
#
#  Sales data shape (10, 5)
# [[     1 150000 180000 220000 250000]
#  [     2 280000 310000 350000 390000]
#  [     3  50000  65000  85000 110000]]

# %%
# total sales per year

print(np.sum(sales_data,axis=0))
print('yearly total ',np.sum(sales_data[:,1:],axis=0))
# Out:
# [     55 1620000 1850000 2084000 2298000]
# yearly total  [1620000 1850000 2084000 2298000]

# %%
cumelativeSum = np.cumsum(sales_data[:,1:],axis=1)
print(cumelativeSum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumelativeSum,axis=0))
#plt.plot(np.mean(cumelativeSum,axis=1))
# Out:
# [[ 150000  330000  550000  800000]
#  [ 280000  590000  940000 1330000]
#  [  50000  115000  200000  310000]
#  [ 120000  260000  425000  600000]
#  [ 450000  930000 1440000 1970000]
#  [  30000   65000   97000  137000]
#  [  90000  200000  330000  480000]
#  [ 200000  440000  710000 1010000]
#  [  70000  155000  247000  345000]
#  [ 180000  385000  615000  870000]]
